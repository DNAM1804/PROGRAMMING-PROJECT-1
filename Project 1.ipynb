# %% [markdown]
# ## NAME: MENSAH DORA NAA AYORKOR

# %% [markdown]
# ## STUDENT'S IDENTIFICATION : 10984530

# %% [markdown]
# ## PROGRAMME: BIOMEDICAL ENGINEERING

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data = pd.read_csv('data.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %%
data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
data.head()
# Out:
#    ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   1            7.4              0.70         0.00             1.9
# 1   2            7.8              0.88         0.00             2.6
# 2   3            7.8              0.76         0.04             2.3
# 3   4           11.2              0.28         0.56             1.9
# 4   5            7.4              0.70         0.00             1.9
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970   NaN
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4      5.0
# 1       0.68      9.8      5.0
# 2       0.65      9.8      5.0
# ...

# %% [markdown]
# **This shows the first five values in  the first five row and all columns.**

# %%
data.tail()
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 1596      0.062                 39.0                  51.0  0.99512  3.52
# 1597      0.076                 29.0                  40.0  0.99574  3.42
# 1598      0.075                 32.0                  44.0  0.99547  3.57
# 1599      0.067                 18.0                  42.0  0.99549  3.39
# 1600      0.066                 22.0                  48.0  0.99494  3.30
#
#       sulphates  alcohol  quality
# 1596       0.76     11.2      6.0
# ...

# %% [markdown]
# **This shows the last five values of the last five rows and all columns.**

# %% [markdown]
# **From the data above, we can deduce that there are null values in our data.Therefore we have to deal with null values first before the data is ready for use.**

# %% [markdown]
# # CLEANING AND PRE-PROCESSING DATA.

# %% [markdown]
# *CHECKING AND REMOVING DUPLICATE ROWS.*

# %% [markdown]
# *Before dealing with null values,we have to check for duplicate rows and remove them, so as not to make our work tedious and also improve the presentability of our work.*

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1596    False
# 1597    False
# 1598    False
# 1599    False
# 1600    False
# Length: 1601, dtype: bool

# %% [markdown]
# **Even though the code that we run was able to show that the first and last five rows do not have duplicate values, it is not enough evidence to show us that all the rows are not duplicates of themselves. Through the summation of duplicates, we can find the number of duplicate rows they are and deal with them.**

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Given that, the summation is zero, we can now conclude that we have no duplicate rows in  our data.**

# %% [markdown]
# ## DEALING WITH NULL VALUES.

# %% [markdown]
# *To be able to properly deal with null values, we can check the number of null values each column has.*

# %%
data.isnull().sum()
# Out:
# ID                      0
# fixed acidity           1
# volatile acidity        0
# citric acid             1
# residual sugar          0
# chlorides               3
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 1
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %% [markdown]
# **The data type we have is a large one (1601 rows and 13 columns) so these null values would not really cause a dent in our analysis therefore we can drop some of them.**

# %%
data =data.dropna(subset=['fixed acidity','citric acid','chlorides','free sulfur dioxide','total sulfur dioxide','density','quality'])

# %%
data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# **The variable name used was still data so we would not have to keep interchanging between the old and the clean dataset.**

# %%
data.isnull().sum()
# Out:
# ID                      0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# **For the pH null value, we can replace it with the mean value of all the pH's since the mean shows the average value in the column's values. Since the null value is not around the middle portion of the column,we decided not to use the median and we chose not to use the mode to maintain slight difference in results.**

# %%
data.pH
# Out:
# 0       3.51
# 1       3.20
# 2        NaN
# 3       3.16
# 4       3.51
#         ...
# 1596    3.52
# 1597    3.42
# 1598    3.57
# 1599    3.39
# 1600    3.30
# Name: pH, Length: 1592, dtype: float64

# %%
mean_pH =data.pH.mean()

# %%
mean_pH
# Out:
# 3.311357636706474

# %%
data.loc[2,'pH'] = 3.31

# %%
data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# *The job of a data anyalyst is to inspect, transform and model data to be able to draw comprehenensive conclusions that will aid in decision making.From the new dataset we are working with, we can reason that we were given a number of red wines and certain specific factors or attributes that affect the quality of the wine.From the statistical inference of the entire dataset and the individual coulmns, we can show investors how we have been able to improve on the quality of our red wine and also be able to gain other information from our inference.*

# %% [markdown]
# ## STATISTICAL INFERENCE ON DATA SET.

# %%
data.describe()
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1592.000000    1592.000000       1592.000000  1592.000000
# mean    800.559673       8.320289          0.527827     0.271332
# std     461.030208       1.739636          0.179084     0.194832
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.750000       7.100000          0.390000     0.090000
# 50%     800.500000       7.900000          0.520000     0.260000
# 75%    1199.250000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1592.000000  1592.000000          1592.000000           1592.000000
# mean         2.540609     0.087503            15.861181             46.503141
# std          1.412644     0.047160            10.426129             32.988822
# ...

# %% [markdown]
# **Where the count represents the number of items in each column, mean represents the average of each column, std represents the standard deviation, min and max represent the minimum and maximum values and the 20%,50% and 75% represent percentiles.**

# %% [markdown]
# ## STATISTICAL INFERENCE  OF COLUMNS AND HIDDEN INFERENCES.

# %% [markdown]
# **To begin, we can check the mean, mode and median of each atrribute(each column).**

# %%
mean_fa = data['fixed acidity'].mean()

# %%
mean_fa
# Out:
# 8.320288944723618

# %%
mean_va = data['volatile acidity'].mean()

# %%
mean_va
# Out:
# 0.5278266331658291

# %%
mean_ca = data['citric acid'].mean()

# %%
mean_ca
# Out:
# 0.27133165829145733

# %%
mean_rs = data['residual sugar'].mean()

# %%
mean_rs
# Out:
# 2.540609296482412

# %%
chlorides_mean = data['chlorides'].mean()

# %%
chlorides_mean
# Out:
# 0.08750251256281405

# %%
mean_fsd = data['free sulfur dioxide'].mean()

# %%
mean_fsd
# Out:
# 15.861180904522612

# %%
mean_tsd = data['total sulfur dioxide'].mean()

# %%
mean_tsd
# Out:
# 46.50314070351759

# %%
density_mean = data['density'].mean()

# %%
density_mean
# Out:
# 0.9967466896984926

# %%
mean_pH
# Out:
# 3.311357636706474

# %%
mean_sulphates =data['sulphates'].mean()

# %%
mean_sulphates
# Out:
# 0.6586055276381909

# %%
mean_alcohol = data['alcohol'].mean()

# %%
mean_alcohol
# Out:
# 10.425659547738695

# %%
mean_quality = data['quality'].mean()

# %%
mean_quality
# Out:
# 5.6375628140703515

# %%
mode_quality= data['quality'].mode()

# %%
mode_quality
# Out:
# 0    5.0
# Name: quality, dtype: float64

# %%
print(data['quality'].median())
# Out:
# 6.0

# %%
print(data['fixed acidity'].median())
# Out:
# 7.9

# %%
print(data['volatile acidity'].median())
# Out:
# 0.52

# %%
print(data['citric acid'].median())
# Out:
# 0.26

# %%
print(data['residual sugar'].median())
# Out:
# 2.2

# %%
print(data['chlorides'].median())
# Out:
# 0.079

# %%
print(data['free sulfur dioxide'].median())
# Out:
# 14.0

# %%
print(data['total sulfur dioxide'].median())
# Out:
# 38.0

# %%
print(data['pH'].median())
# Out:
# 3.31

# %%
print(data['sulphates'].median())
# Out:
# 0.62

# %%
print(data['alcohol'].median())
# Out:
# 10.2

# %%
print(data['alcohol'].mode())
# Out:
# 0    9.5
# Name: alcohol, dtype: float64

# %%
print(data['sulphates'].mode())
# Out:
# 0    0.6
# Name: sulphates, dtype: float64

# %%
print(data['pH'].mode())
# Out:
# 0    3.3
# Name: pH, dtype: float64

# %%
print(data['total sulfur dioxide'].mode())
# Out:
# 0    28.0
# Name: total sulfur dioxide, dtype: float64

# %%
print(data['free sulfur dioxide'].mode())
# Out:
# 0    6.0
# Name: free sulfur dioxide, dtype: float64

# %%
print(data['chlorides'].mode())
# Out:
# 0    0.08
# Name: chlorides, dtype: float64

# %%
print(data['residual sugar'].mode())
# Out:
# 0    2.0
# Name: residual sugar, dtype: float64

# %%
print(data['citric acid'].mode())
# Out:
# 0    0.0
# Name: citric acid, dtype: float64

# %%
print(data['volatile acidity'].mode())
# Out:
# 0    0.6
# Name: volatile acidity, dtype: float64

# %%
print(data['fixed acidity'].mode())
# Out:
# 0    7.2
# Name: fixed acidity, dtype: float64

# %% [markdown]
# *Above are a few statistic inferences of the attributes of the dataset.*

# %% [markdown]
# **From the calculation of the average quality of wine, we get an estimated value of 6 for the quality of the red wine we have been able to produce from the dataset we have.We can then compare how many wines were above the average and below the average.**

# %%
ID = data.ID

# %%
ID
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 1596    1597
# 1597    1598
# 1598    1599
# 1599    1600
# 1600    1601
# Name: ID, Length: 1592, dtype: int64

# %%
above_mq =ID.gt(5.6375628140703515)

# %%
above_mq
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1596     True
# 1597     True
# 1598     True
# 1599     True
# 1600     True
# Name: ID, Length: 1592, dtype: bool

# %%
above_mq.sum()
# Out:
# 1587

# %%
below_mq = ID.lt(5.6375628140703515)

# %%
below_mq
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1596    False
# 1597    False
# 1598    False
# 1599    False
# 1600    False
# Name: ID, Length: 1592, dtype: bool

# %%
below_mq.sum()
# Out:
# 5

# %% [markdown]
# **The results from the above show that 1587 wines have quality that is above the average quality and only 5 that are below average. This shows that majority of the wines(more than 90%) produced have great quality and the five that are below average are insignificant.**

# %%
plot_data = [above_mq.sum(),below_mq.sum() ]
plot_colours = ['yellow','green']
plot_labels = ['number of wine above mean quality', 'number of wine below mean quality']

# %%
plt.pie(plot_data,labels = plot_labels,colors = plot_colours)
plt.title('Comparison between above average and below average wine.')
plt.show()

# %%
data.quality
# Out:
# 0       5.0
# 1       5.0
# 2       5.0
# 3       6.0
# 4       5.0
#        ...
# 1596    6.0
# 1597    6.0
# 1598    5.0
# 1599    6.0
# 1600    6.0
# Name: quality, Length: 1592, dtype: float64

# %%
sns.histplot(data.quality)
plt.title('RED WINE QUALITY DISTRIBUTION.')
plt.show()

# %% [markdown]
# **We can now review the factors in the dataset and show their contributions towards the quality of majority of the wines. We can group them into five;the acids(which include citric acid, fixed acidity volatile acidity and pH),sugar and salt (which consist of the residual sugar,chlorides and sulphates),sulfur(the free and total sulfur dioxide),alcohol and density.**

# %%
sns.histplot(data['fixed acidity'],color = 'black')
plt.title('FIXED ACIDITY DISTRIBUTION.')
plt.show()

# %%
sns.histplot(data['volatile acidity'], color = 'black')
plt.title('VOLATILE ACIDITY DISTRIBUTION.')
plt.show()

# %%
sns.histplot(data['citric acid'],color = 'black')
plt.title('CITRIC ACID DISTRIBUTITION.')
plt.show()

# %%
sns.histplot(data.pH,color = 'black')
plt.title('pH DISTRIBUTION.')
plt.show()

# %% [markdown]
# ## ACIDS

# %%
sns.histplot(data['residual sugar'],color = 'black')
plt.title('DISTRIBUTION OF RESIDUAL SUGAR.')
plt.show()

# %%
sns.histplot(data.chlorides,color = 'black')
plt.title('CHLORIDES DISTRIBUTION.')
plt.show()

# %%
sns.histplot(data.sulphates,color = 'black')
plt.title('DISTRIBUTION OF SULPHATES.')
plt.show()

# %% [markdown]
# ## SUGARS AND SALTS

# %%
sns.histplot(data['free sulfur dioxide'],color = 'black')
plt.title('FREE SULFUR DIOXIDE DISTRIBUTION.')
plt.show()

# %%
sns.histplot(data['total sulfur dioxide'],color = 'black')
plt.title('TOTAL SULFUR DIOXIDE DISTRIBUTION.')
plt.show()

# %% [markdown]
# ## **SULFURS**

# %%
sns.histplot(data.density,color = 'black')
plt.title('DENSITY DISTRIBUTION.')
plt.show()

# %%
sns.histplot(data.alcohol,color = 'black')
plt.title('DISTRIBUTION OF ALCOHOL.')
plt.show()

# %% [markdown]
# *The graphs show the individual columns and the values in them and the number of times they occur the most.*

# %%
all_column =['fixed acidity','volatile acidity','citric acid','residual sugar', 'chlorides','free sulfur dioxide','total sulfur dioxide','pH','sulphates','alcohol']

# %%
for column in all_column:
    above_quality=data[data['quality']==7.0][all_column]
    below_quality=data[data['quality']==5.0][all_column]

# %%
plt.figure(figsize=(10,8))
sns.histplot(above_quality,bins=50, label = 'Greater')
sns.histplot(below_quality,bins=50, label = 'Less')
plt.legend(loc="upper right")
plt.title(f'ABOVE AND BELOW AVERAGE MEAN QUALITY HISTOGRAM FOR {all_column}')
# Out:
# Text(0.5, 1.0, "ABOVE AND BELOW AVERAGE MEAN QUALITY HISTOGRAM FOR ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'pH', 'sulphates', 'alcohol']")

# %% [markdown]
# **This graph shows the values which are greater than and less than. For greater than, it wil hold if the value is actually  equal to 7.0and for less than,5.0)**

# %%
mean_ca = data['citric acid'].mean()

# %%
mean_ca
# Out:
# 0.27133165829145733

# %%
collating_values= data['citric acid']< mean_ca

# %%
plt.pie(collating_values.value_counts(),labels = ['Values less that mean citric acid','Values greater than mean citric acid'], colors=['Red','Green'])
plt.title('COMPARING BELOW AND ABOVE AVERAGE VALUES OF CITRIC ACID.')
plt.show()

# %% [markdown]
# **This graph compares values that are more and less than the average citric acid value.**

# %%
salts_data= data.filter(items=['chlorides','sulphates'])

# %%
salts_data
# Out:
#       chlorides  sulphates
# 0         0.076       0.56
# 1         0.098       0.68
# 2         0.092       0.65
# 3         0.075       0.58
# 4         0.076       0.56
# ...         ...        ...
# 1596      0.062       0.76
# 1597      0.076       0.75
# 1598      0.075       0.71
# 1599      0.067       0.66
# 1600      0.066       0.84
#
# [1592 rows x 2 columns]

# %%
sns.histplot(salts_data)
plt.savefig('image.png')
plt.show()

# %% [markdown]
# **Graph represents the salts,sulphates and chloride.**

# %% [markdown]
# ## DATA CORRELATION

# %%
fa_values = data.groupby('fixed acidity').count().sort_values(by ='quality',ascending= False)["quality"][:7.3]

# %%
fa_values
# Out:
# fixed acidity
# 7.2    68
# 7.1    57
# 7.5    52
# 7.8    52
# 7.7    50
# 7.0    50
# 7.6    46
# 6.8    46
# 8.2    45
# 7.4    44
# 7.3    44
# Name: quality, dtype: int64

# %%
axes = fa_values.plot.bar(rot=0,stacked=True,color="green")
plt.title('HIGHEST ELEVEN FIXED ACIDITY VALUES IN TERMS OF QUALITY')
# Out:
# Text(0.5, 1.0, 'HIGHEST ELEVEN FIXED ACIDITY VALUES IN TERMS OF QUALITY')

# %%
fa_values.count()
# Out:
# 11

# %% [markdown]
# **This bar graph shows the relationship between some fixed acidity values and the quality in descending order.We see that, as the quality of the red decreases , there is a rise and fall of the value of fixed acidity in which the difference between values of the fixed acid column are almost insignificant.**

# %%
sns.relplot(data, x= 'density',y='residual sugar',color= 'brown', s=40)
plt.savefig('image2.png')
plt.title('RELATIONSHIP BETWEEN ALCOHOL AND RESIDUAL SUGAR')
plt.show()

# %% [markdown]
# **From this graph,we see that there is not much relationship between alcohol and residual sugar because ponts are scattered and are not positioned in any proper form.**

# %%
data.corr()
# Out:
#                             ID  fixed acidity  volatile acidity  citric acid  \
# ID                    1.000000      -0.267786         -0.008233    -0.155203
# fixed acidity        -0.267786       1.000000         -0.256838     0.672213
# volatile acidity     -0.008233      -0.256838          1.000000    -0.551943
# citric acid          -0.155203       0.672213         -0.551943     1.000000
# residual sugar       -0.031564       0.114867          0.001196     0.143794
# chlorides            -0.119921       0.093836          0.061247     0.204132
# free sulfur dioxide   0.085625      -0.150241         -0.014658    -0.057532
# total sulfur dioxide -0.115931      -0.111029          0.074277     0.038405
# density              -0.368675       0.666828          0.022602     0.363917
# pH                    0.133274      -0.683767          0.234120    -0.542983
# sulphates            -0.127222       0.184942         -0.261775     0.313429
# ...

# %% [markdown]
# **From the dataset given here, we can see the connection between the various factors that affect the quality of wine with other factors.The table shows a sort of interconnection between the factors.Correlation between attributes and themselves gives 1.At the poinnts where there are negatives, it shows that there is a negative correlation (connection) between the factors.On the last row, we see that the quality of the red wine is greatly affected by the alcohol and not really affected by the pH, residual sugar, density,chlorides,free and total sulfur dioxide .**

# %%
sns.relplot(data, x= 'free sulfur dioxide',y='total sulfur dioxide',color= 'red', s=30)
plt.title('CORRELATION BETWEEN FREE SULFUR DIOXIDE AND TOTAL SULFUR DIOXIDE')
plt.show()

# %% [markdown]
# **This shows a low positive corerlation between free and total sulfur dioxide since the points seem to be concentrated at a point but seems to be following a straight line.**

# %%
sns.relplot(data, x= 'fixed acidity',y='volatile acidity',color= 'grey', s=40)
plt.savefig('image2.png')
plt.title('RELATIONSHIP BETWEEN FIXED ACIDITY AND VOLATILE ACIDITY')
plt.show()

# %% [markdown]
# **From the scatter plot,we can deduce that there is no correlation as the points plotted are scattered and follow no definite pattern.**

# %%
sns.relplot(data, x= 'quality',y='alcohol',color= 'black', s=30)
plt.title('RELATIONSHIP BETWEEN QUALITY AND ALCOHOL')
plt.show()

# %% [markdown]
# **Here, both variables alcohol and quality are continuous,discrete and dense.**

# %%
sns.heatmap(data.corr(),annot =True) 
plt.figure(figsize=(20,10))
plt.savefig('image3.png')
plt.show()

# %% [markdown]
# **A heat map shows the relationship between two variables, one plotted on the x and the other on the y-axis. From our heat map, we can tell how one factor is changing with respect to the other factors.It is almost similar to the data correlation function.The only difference is that we use the warmness or the coolness of color to ahiw how it is changing with respect to the other factors. Here the factors against themselves is shown by theplain white boxes.The lower the value, the darker the colour becomes. From the heatmap, we can tell that alcohol has a lot of influence on the quality of the red wine since it has a light color and which means its value in relation to the quality is high.Other hidden inferences can be shown on the heat map.**

# %% [markdown]
# ## CONCLUSION.

# %% [markdown]
# **From our exploration of the data, we realize that, at the end of the year, majority of the wines that were produced were of high quality(that is, when we compared their quality to the mean quality,they were higher than it.).We noticed that, at the end of the year,the red wines that had high quality were mostly so due to certain factors like the amount of alcohol(these were shown by inferences drawn from the heat map and the data correlation table.) We also tried to see how the other attributes of red wine were connected and how they affected themselves and we can conclude that, some of the attributes had little to no effect on each other while some had major effects on other(for example,from the scatter plot, we saw that there was little to no correlation between fixed acidity and volatile acidity,and this was further backed by values on the heat map and data correlation table.). Here, in this Beverage Manufacturing Company, we pride ourselves of creating products of good quality and from this analysis we have made, we can conclude that if investors see the stastistics and inferences drawn here it can move them to fund the company to be able to create more products of high quality and in turn increase profit of the company and also increase returns on investments made by the investors.**
